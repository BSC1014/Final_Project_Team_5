# %%
#import pandas module
import pandas as pd
import numpy

# %%
# Reading the Calendar csv file into a dataframe
calendar_df = pd.read_csv("calendar.csv")
calendar_df
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 2            241032  2016-01-06         f     NaN
# 3            241032  2016-01-07         f     NaN
# 4            241032  2016-01-08         f     NaN
# ...             ...         ...       ...     ...
# 1393565    10208623  2016-12-29         f     NaN
# 1393566    10208623  2016-12-30         f     NaN
# 1393567    10208623  2016-12-31         f     NaN
# 1393568    10208623  2017-01-01         f     NaN
# 1393569    10208623  2017-01-02         f     NaN
#
# [1393570 rows x 4 columns]

# %%
# Summary overview of the calendar csv file
calendar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB

# %%
# Check for null values
calendar_df.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price         459028
# dtype: int64

# %%
# Percentage of missing values in each column
calendar_df.isnull().mean()
# Out:
# listing_id    0.00000
# date          0.00000
# available     0.00000
# price         0.32939
# dtype: float64

# %%
# Reading the Reviews csv file
reviews_df = pd.read_csv("reviews.csv")
reviews_df
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 0         7202016  38917982  2015-07-19     28943674        Bianca
# 1         7202016  39087409  2015-07-20     32440555         Frank
# 2         7202016  39820030  2015-07-26     37722850           Ian
# 3         7202016  40813543  2015-08-02     33671805        George
# 4         7202016  41986501  2015-08-10     34959538          Ming
# ...           ...       ...         ...          ...           ...
# 84844     3624990  50436321  2015-10-12     37419458          Ryan
# 84845     3624990  51024875  2015-10-17      6933252         Linda
# 84846     3624990  51511988  2015-10-20     19543701         Jaime
# 84847     3624990  52814482  2015-11-02     24445024        Jørgen
# 84848     9727246  56429621  2015-12-13     30860360     Stephanie
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# ...

# %%
# Summary overview of the reviews csv file
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     84849 non-null  int64
#  1   id             84849 non-null  int64
#  2   date           84849 non-null  object
#  3   reviewer_id    84849 non-null  int64
#  4   reviewer_name  84849 non-null  object
#  5   comments       84831 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.9+ MB

# %%
#Covert the date dtype to a datetime dtype
reviews_df['date']= pd.to_datetime(reviews_df['date'])
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     84849 non-null  int64
#  1   id             84849 non-null  int64
#  2   date           84849 non-null  datetime64[ns]
#  3   reviewer_id    84849 non-null  int64
#  4   reviewer_name  84849 non-null  object
#  5   comments       84831 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 3.9+ MB

# %%
# Check for null values
reviews_df.isnull().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         18
# dtype: int64

# %%
# Percentage of missing values in each column
reviews_df.isnull().mean()
# Out:
# listing_id       0.000000
# id               0.000000
# date             0.000000
# reviewer_id      0.000000
# reviewer_name    0.000000
# comments         0.000212
# dtype: float64

# %%
# Drop the name column for columns we will not be utilizing for our project to answer our question
reviews_df = reviews_df.drop(['comments'], axis=1)
reviews_df.head(5)
# Out:
#    listing_id        id       date  reviewer_id reviewer_name
# 0     7202016  38917982 2015-07-19     28943674        Bianca
# 1     7202016  39087409 2015-07-20     32440555         Frank
# 2     7202016  39820030 2015-07-26     37722850           Ian
# 3     7202016  40813543 2015-08-02     33671805        George
# 4     7202016  41986501 2015-08-10     34959538          Ming

# %%
# Reading the listing csv file
listings_df = pd.read_csv("listings.csv")
listings_df
# Out:
#             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# ...

# %%
# Summary overview of the reviews csv file
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
# Check for null values for listings_df
listings_null_columns=listings_df.columns[listings_df.isnull().any()]
listings_df[listings_null_columns].isnull().sum()
# Out:
# summary                         177
# space                           569
# neighborhood_overview          1032
# notes                          1606
# transit                         934
# thumbnail_url                   320
# medium_url                      320
# xl_picture_url                  320
# host_name                         2
# host_since                        2
# host_location                     8
# host_about                      859
# host_response_time              523
# host_response_rate              523
# host_acceptance_rate            773
# host_is_superhost                 2
# host_thumbnail_url                2
# host_picture_url                  2
# host_neighbourhood              300
# host_listings_count               2
# host_total_listings_count         2
# host_has_profile_pic              2
# host_identity_verified            2
# neighbourhood                   416
# zipcode                           7
# property_type                     1
# ...

# %%
# Percentage of missing values in each column
listings_df[listings_null_columns].isnull().mean()
# Out:
# summary                        0.046359
# space                          0.149031
# neighborhood_overview          0.270299
# notes                          0.420639
# transit                        0.244631
# thumbnail_url                  0.083814
# medium_url                     0.083814
# xl_picture_url                 0.083814
# host_name                      0.000524
# host_since                     0.000524
# host_location                  0.002095
# host_about                     0.224987
# host_response_time             0.136983
# host_response_rate             0.136983
# host_acceptance_rate           0.202462
# host_is_superhost              0.000524
# host_thumbnail_url             0.000524
# host_picture_url               0.000524
# host_neighbourhood             0.078575
# host_listings_count            0.000524
# host_total_listings_count      0.000524
# host_has_profile_pic           0.000524
# host_identity_verified         0.000524
# ...

# %%
# Drop the name column for columns we will not be utilizing for our project to answer our question
cleaned_listings_df = listings_df.drop(['listing_url', 'scrape_id', 'last_scraped', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_thumbnail_url', 'host_picture_url', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'country_code', 'is_location_exact', 'amenities', 'jurisdiction_names', 'require_guest_profile_picture', 'calculated_host_listings_count', 'license', 'calendar_last_scraped', 'square_feet', 'host_about'], axis=1)
listings_df.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
# Percentage of missing values in each column
cleaned_listings_df.isnull().mean()
# Out:
# id                                  0.000000
# name                                0.000000
# host_id                             0.000000
# host_name                           0.000524
# host_since                          0.000524
# host_location                       0.002095
# host_response_time                  0.136983
# host_response_rate                  0.136983
# host_acceptance_rate                0.202462
# host_is_superhost                   0.000524
# host_neighbourhood                  0.078575
# host_listings_count                 0.000524
# host_total_listings_count           0.000524
# neighbourhood_group_cleansed        0.000000
# city                                0.000000
# state                               0.000000
# zipcode                             0.001833
# market                              0.000000
# smart_location                      0.000000
# country                             0.000000
# latitude                            0.000000
# ...

# %%
#Covert the host_since dtype to a datetime dtype
cleaned_listings_df['host_since']= pd.to_datetime(listings_df['host_since'])

# %%
#Covert the first_review dtype to a datetime dtype
cleaned_listings_df['first_review']= pd.to_datetime(listings_df['first_review'])

# %%
#Covert the last_review dtype to a datetime dtype
cleaned_listings_df['last_review']= pd.to_datetime(listings_df['last_review'])

# %%
#Remove the $ in the price to convert it from a string to a float
cleaned_listings_df['price'] = listings_df['price'].replace("[$,]", "", regex=True).astype(float)

# %%
#Remove the $ in the price to convert it from a string to a float
cleaned_listings_df['weekly_price'] = listings_df['weekly_price'].replace("[$,]", "", regex=True).astype(float)

# %%
#Remove the $ in the price to convert it from a string to a float
cleaned_listings_df['monthly_price'] = listings_df['monthly_price'].replace("[$,]", "", regex=True).astype(float)

# %%
#Remove the $ in the price to convert it from a string to a float
cleaned_listings_df['security_deposit'] = listings_df['security_deposit'].replace("[$,]", "", regex=True).astype(float)

# %%
#Remove the $ in the price to convert it from a string to a float
cleaned_listings_df['cleaning_fee'] = listings_df['cleaning_fee'].replace("[$,]", "", regex=True).astype(float)

# %%
#Remove the $ in the price to convert it from a string to a float
cleaned_listings_df['extra_people'] = listings_df['extra_people'].replace("[$,]", "", regex=True).astype(float)

# %%
#Remove the % in the percentage to convert it from a string to a float
cleaned_listings_df['host_response_rate'] = listings_df['host_response_rate'].replace("[%,]", "", regex=True).astype(float)

# %%
#Remove the % in the percentage to convert it from a string to a float
cleaned_listings_df['host_acceptance_rate'] = listings_df['host_acceptance_rate'].replace("[%,]", "", regex=True).astype(float)

# %%
# Checking the dtypes once again to make sure everything converted properly
cleaned_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   name                              3818 non-null   object
#  2   host_id                           3818 non-null   int64
#  3   host_name                         3816 non-null   object
#  4   host_since                        3816 non-null   datetime64[ns]
#  5   host_location                     3810 non-null   object
#  6   host_response_time                3295 non-null   object
#  7   host_response_rate                3295 non-null   float64
#  8   host_acceptance_rate              3045 non-null   float64
#  9   host_is_superhost                 3816 non-null   object
#  10  host_neighbourhood                3518 non-null   object
# ...

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['host_response_rate'].fillna(value=cleaned_listings_df['host_response_rate'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['host_acceptance_rate'].fillna(value=cleaned_listings_df['host_acceptance_rate'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['host_listings_count'].fillna(value=cleaned_listings_df['host_listings_count'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['host_total_listings_count'].fillna(value=cleaned_listings_df['host_total_listings_count'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['accommodates'].fillna(value=cleaned_listings_df['accommodates'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['bathrooms'].fillna(value=cleaned_listings_df['bathrooms'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['bedrooms'].fillna(value=cleaned_listings_df['bedrooms'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['beds'].fillna(value=cleaned_listings_df['beds'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['price'].fillna(value=cleaned_listings_df['price'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['cleaning_fee'].fillna(value=cleaned_listings_df['cleaning_fee'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['guests_included'].fillna(value=cleaned_listings_df['guests_included'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['extra_people'].fillna(value=cleaned_listings_df['extra_people'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['minimum_nights'].fillna(value=cleaned_listings_df['minimum_nights'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['maximum_nights'].fillna(value=cleaned_listings_df['maximum_nights'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['availability_30'].fillna(value=cleaned_listings_df['availability_30'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['availability_60'].fillna(value=cleaned_listings_df['availability_60'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['availability_90'].fillna(value=cleaned_listings_df['availability_90'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['availability_365'].fillna(value=cleaned_listings_df['availability_365'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_rating'].fillna(value=cleaned_listings_df['review_scores_rating'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_accuracy'].fillna(value=cleaned_listings_df['review_scores_accuracy'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_cleanliness'].fillna(value=cleaned_listings_df['review_scores_cleanliness'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_checkin'].fillna(value=cleaned_listings_df['review_scores_checkin'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_communication'].fillna(value=cleaned_listings_df['review_scores_communication'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_location'].fillna(value=listings_df['review_scores_location'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['review_scores_value'].fillna(value=cleaned_listings_df['review_scores_value'].mean(), inplace=True)

# %%
#Fill in nulls with the mean of that column
cleaned_listings_df['reviews_per_month'].fillna(value=cleaned_listings_df['reviews_per_month'].mean(), inplace=True)

# %%
#Fill in nulls using the ffill option
cleaned_listings_df["zipcode"].fillna(method ='ffill', inplace = True)

# %%
#Fill in nulls using the ffill option
cleaned_listings_df["host_is_superhost"].fillna(method ='ffill', inplace = True)

# %%
# Summary of the null values after filling in the nulls
cleaned_listings_df.isnull().sum()
# Out:
# id                                     0
# name                                   0
# host_id                                0
# host_name                              2
# host_since                             2
# host_location                          8
# host_response_time                   523
# host_response_rate                     0
# host_acceptance_rate                   0
# host_is_superhost                      0
# host_neighbourhood                   300
# host_listings_count                    0
# host_total_listings_count              0
# neighbourhood_group_cleansed           0
# city                                   0
# state                                  0
# zipcode                                0
# market                                 0
# smart_location                         0
# country                                0
# latitude                               0
# longitude                              0
# property_type                          1
# ...

# %%
cleaned_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   name                              3818 non-null   object
#  2   host_id                           3818 non-null   int64
#  3   host_name                         3816 non-null   object
#  4   host_since                        3816 non-null   datetime64[ns]
#  5   host_location                     3810 non-null   object
#  6   host_response_time                3295 non-null   object
#  7   host_response_rate                3818 non-null   float64
#  8   host_acceptance_rate              3818 non-null   float64
#  9   host_is_superhost                 3818 non-null   object
#  10  host_neighbourhood                3518 non-null   object
# ...

# %%
#Checking to see if there are non-digits in the zipcode column to covert from an object to a numberical dtype
if (cleaned_listings_df['zipcode'].astype(str).str.isdigit()).all():
    cleaned_listings_df['zipcode'] = cleaned_listings_df['zipcode'].astype(int)
else:
    print("Not all values in the column are digits.")
# Out:
# Not all values in the column are digits.

# %%
#Convert all non-numerical values to a null value to convert to a numerical dtype
cleaned_listings_df['zipcode'] = pd.to_numeric(cleaned_listings_df['zipcode'], errors='coerce')

# %%
#Seeing if the dtype changed
cleaned_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   name                              3818 non-null   object
#  2   host_id                           3818 non-null   int64
#  3   host_name                         3816 non-null   object
#  4   host_since                        3816 non-null   datetime64[ns]
#  5   host_location                     3810 non-null   object
#  6   host_response_time                3295 non-null   object
#  7   host_response_rate                3818 non-null   float64
#  8   host_acceptance_rate              3818 non-null   float64
#  9   host_is_superhost                 3818 non-null   object
#  10  host_neighbourhood                3518 non-null   object
# ...

# %%
# Summary of the null values after filling in the nulls - zipcode now has 1 null value
cleaned_listings_df.isnull().sum()
# Out:
# id                                     0
# name                                   0
# host_id                                0
# host_name                              2
# host_since                             2
# host_location                          8
# host_response_time                   523
# host_response_rate                     0
# host_acceptance_rate                   0
# host_is_superhost                      0
# host_neighbourhood                   300
# host_listings_count                    0
# host_total_listings_count              0
# neighbourhood_group_cleansed           0
# city                                   0
# state                                  0
# zipcode                                1
# market                                 0
# smart_location                         0
# country                                0
# latitude                               0
# longitude                              0
# property_type                          1
# ...

# %%
#Fill in nulls using the ffill option
cleaned_listings_df["zipcode"].fillna(method ='ffill', inplace = True)

# %%
#Convert it from a float to an integer
cleaned_listings_df['zipcode'] = cleaned_listings_df['zipcode'].astype(int)

# %%
#Fill in nulls with ffill
cleaned_listings_df["property_type"].fillna(method ='ffill', inplace = True)

# %%
#Making sure property_type's 1 null was filled in
cleaned_listings_df.isnull().sum()
# Out:
# id                                     0
# name                                   0
# host_id                                0
# host_name                              2
# host_since                             2
# host_location                          8
# host_response_time                   523
# host_response_rate                     0
# host_acceptance_rate                   0
# host_is_superhost                      0
# host_neighbourhood                   300
# host_listings_count                    0
# host_total_listings_count              0
# neighbourhood_group_cleansed           0
# city                                   0
# state                                  0
# zipcode                                0
# market                                 0
# smart_location                         0
# country                                0
# latitude                               0
# longitude                              0
# property_type                          0
# ...

# %%
cleaned_listings_df.head(10)
# Out:
#         id                                 name   host_id      host_name  \
# 0   241032         Stylish Queen Anne Apartment    956883          Maija
# 1   953595   Bright & Airy Queen Anne Apartment   5177328         Andrea
# 2  3308979  New Modern House-Amazing water view  16708587           Jill
# 3  7421966                   Queen Anne Chateau   9851441          Emily
# 4   278830       Charming craftsman 3 bdm house   1452570          Emily
# 5  5956968      Private unit in a 1920s mansion    326758         Andrew
# 6  1909058      Queen Anne Private Bed and Bath   2497928  Gary And Beth
# 7   856550    Tiny Garden cabin on Queen Anne     4016632      Jean-Marc
# 8  4948745     Urban Charm || Downtown || Views   2166277          Aliza
# 9  2493658   Airy + Bright Queen Anne Apartment   5177328         Andrea
#
#   host_since                       host_location  host_response_time  \
# 0 2011-08-11  Seattle, Washington, United States  within a few hours
# ...

# %%
#Convert host_is_superhost from T/F, to 0/1
cleaned_listings_df['host_is_superhost'] = cleaned_listings_df['host_is_superhost'].map({'t': 1, 'f': 0})

# %%
#Convert has_availability from T/F, to 0/1
cleaned_listings_df['has_availability'] = cleaned_listings_df['has_availability'].map({'t': 1, 'f': 0})

# %%
#Convert instant_bookable from T/F, to 0/1
cleaned_listings_df['instant_bookable'] = cleaned_listings_df['instant_bookable'].map({'t': 1, 'f': 0})

# %%
#Making things transferred appropriately
cleaned_listings_df.head(5)
# Out:
#         id                                 name   host_id host_name  \
# 0   241032         Stylish Queen Anne Apartment    956883     Maija
# 1   953595   Bright & Airy Queen Anne Apartment   5177328    Andrea
# 2  3308979  New Modern House-Amazing water view  16708587      Jill
# 3  7421966                   Queen Anne Chateau   9851441     Emily
# 4   278830       Charming craftsman 3 bdm house   1452570     Emily
#
#   host_since                       host_location  host_response_time  \
# 0 2011-08-11  Seattle, Washington, United States  within a few hours
# 1 2013-02-21  Seattle, Washington, United States      within an hour
# 2 2014-06-12  Seattle, Washington, United States  within a few hours
# 3 2013-11-06  Seattle, Washington, United States                 NaN
# 4 2011-11-29  Seattle, Washington, United States      within an hour
#
#    host_response_rate  host_acceptance_rate  host_is_superhost  ...  \
# 0           96.000000            100.000000                  0  ...
# ...

# %%
#Seeing if the dtype changed
cleaned_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   name                              3818 non-null   object
#  2   host_id                           3818 non-null   int64
#  3   host_name                         3816 non-null   object
#  4   host_since                        3816 non-null   datetime64[ns]
#  5   host_location                     3810 non-null   object
#  6   host_response_time                3295 non-null   object
#  7   host_response_rate                3818 non-null   float64
#  8   host_acceptance_rate              3818 non-null   float64
#  9   host_is_superhost                 3818 non-null   int64
#  10  host_neighbourhood                3518 non-null   object
# ...

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
output_data_file = 'cleaned_airbnb_data.csv'
# Create a CSV file by using the clean_hotel_df DataFrame
cleaned_listings_df.to_csv('cleaned_airbnb_data.csv', encoding='utf8', index=False)
